# %% [markdown]
# # Comprehensive OpenCV Assignment
#
# Follow the instructions in each section and write your code in the provided empty cells using the specified file names.

# %% [markdown]
# ## 1. Reading Images and Videos
# **Task:**
# 1. Read the image `cats.jpg` and display it.
# 2. Read the video `dog.mp4` and display it frame by frame. Ensure the video window closes when the 'd' key is pressed.

# %%
# Write your code here
import cv2 as cv

# Read image
img = cv.imread('opencv_files/cat.jpg')

cv.imshow('Cat Image', img)

# Read video
capture = cv.VideoCapture('opencv_files/dog.mp4')

while True:
    isTrue, frame = capture.read()

    if not isTrue:
        break

    cv.imshow('Dog Video', frame)

    if cv.waitKey(20) & 0xFF == ord('d'):
        break

capture.release()
cv.destroyAllWindows()

# %% [markdown]
# ## 2. Drawing and Text
# **Task:**
# 1. Create a blank image of size $500 \times 500$ with 3 color channels.
# 2. Paint a portion of the image red ($[200:300, 300:400]$).
# 3. Draw a green rectangle from $(0,0)$ to the center of the image.
# 4. Draw a red circle at the center with a radius of 40.
# 5. Draw a white line from $(100, 250)$ to $(300, 400)$.

# %%
# Write your code here
import cv2 as cv
import numpy as np

# Create a blank image of size 500x500 with 3 color channels
blank = np.zeros((500, 500, 3), dtype='uint8')

# Paint a portion red
blank[200:300, 300:400] = (0, 0, 255)

# Draw a green rectangle from (0,0) to center
cv.rectangle(blank, (0, 0), (250, 250), (0, 255, 0), thickness=2)

# Draw a red circle at the center with radius 40
cv.circle(blank, (250, 250), 40, (0, 0, 255), thickness=2)

# Draw a white line from (100,250) to (300,400)
cv.line(blank, (100, 250), (300, 400), (255, 255, 255), thickness=2)

# Display the image
cv.imshow('Drawing and Text', blank)

cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ## 3. Basic Image Functions
# **Task:**
# 1. Load `park.jpg`.
# 2. Convert it to grayscale.
# 3. Apply Gaussian Blur with a $(7,7)$ kernel.
# 4. Perform Canny Edge detection on the blurred image.

# %%
# Write your code here
import cv2 as cv

img = cv.imread('opencv_files/park.jpg')

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

blur = cv.GaussianBlur(gray, (7,7), 0)

canny = cv.Canny(blur, 125, 175)

cv.imshow('Original', img)
cv.imshow('Gray', gray)
cv.imshow('Blur', blur)
cv.imshow('Canny', canny)

cv.waitKey(5000)   # closes after 5 seconds

cv.destroyAllWindows()

# %% [markdown]
# ## 4. Image Transformations
# **Task:**
# 1. Create a function `translate(img, x, y)` to shift an image.
# 2. Create a function `rotate(img, angle, rotPoint=None)` to rotate an image.
# 3. Apply a flip transformation to `park.jpg`.

# %%
# Write your code here
import cv2 as cv
import numpy as np

# Load image
img = cv.imread('opencv_files/park.jpg')

# -----------------------------
# Translation Function
# -----------------------------
def translate(img, x, y):

    # Translation matrix
    transMat = np.float32([
        [1, 0, x],
        [0, 1, y]
    ])

    dimensions = (img.shape[1], img.shape[0])

    return cv.warpAffine(img, transMat, dimensions)


# -----------------------------
# Rotation Function
# -----------------------------
def rotate(img, angle, rotPoint=None):

    (height, width) = img.shape[:2]

    # Rotate around center if no point given
    if rotPoint is None:
        rotPoint = (width // 2, height // 2)

    # Rotation matrix
    rotMat = cv.getRotationMatrix2D(rotPoint, angle, 1.0)

    dimensions = (width, height)

    return cv.warpAffine(img, rotMat, dimensions)


# Apply transformations
translated = translate(img, 100, 100)

rotated = rotate(img, 45)

flipped = cv.flip(img, 1)


# Display images
cv.imshow('Original', img)
cv.imshow('Translated', translated)
cv.imshow('Rotated', rotated)
cv.imshow('Flipped', flipped)

cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ## 5. Contour Detection
# **Task:**
# 1. Load `cats.jpg`.
# 2. Convert to grayscale and apply Gaussian blur.
# 3. Find the edges using Canny.
# 4. Use `cv.findContours` to find all contours.
# 5. Print the count and draw them on a blank image.

# %%
# Write your code here
import cv2 as cv
import numpy as np

# Load image
img = cv.imread('opencv_files/cat.jpg')

# Convert to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# Apply Gaussian Blur
blur = cv.GaussianBlur(gray, (5, 5), 0)

# Perform Canny Edge Detection
canny = cv.Canny(blur, 125, 175)

# Find contours
contours, hierarchies = cv.findContours(
    canny,
    cv.RETR_LIST,
    cv.CHAIN_APPROX_SIMPLE
)

# Print number of contours
print(f'{len(contours)} contour(s) found.')

# Create blank image
blank = np.zeros(img.shape, dtype='uint8')

# Draw contours on blank image
cv.drawContours(blank, contours, -1, (0, 255, 0), 1)

# Display images
cv.imshow('Original Image', img)
cv.imshow('Canny Edges', canny)
cv.imshow('Contours', blank)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 141 contour(s) found.

# %% [markdown]
# ## 6. Color Spaces
# **Task:**
# 1. Load `park.jpg`.
# 2. Convert and display in: Gray, HSV,and RGB.

# %%
# Write your code here
import cv2 as cv

# Load image
img = cv.imread('opencv_files/park.jpg')

# Convert to Gray
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# Convert to HSV
hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)

# Convert to RGB
rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Display images
cv.imshow('Original Image', img)
cv.imshow('Gray Image', gray)
cv.imshow('HSV Image', hsv)
cv.imshow('RGB Image', rgb)

cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ## 7. Smoothing and Blurring
# **Task:**
# 1. Load `cats.jpg`.
# 2. Apply Averaging, Gaussian and Median Blurs

# %%
# Write your code here
import cv2 as cv

# Load image
img = cv.imread('opencv_files/cat.jpg')

# Averaging Blur
average = cv.blur(img, (3, 3))

# Gaussian Blur
gauss = cv.GaussianBlur(img, (3, 3), 0)

# Median Blur
median = cv.medianBlur(img, 3)

# Display images
cv.imshow('Original Image', img)
cv.imshow('Average Blur', average)
cv.imshow('Gaussian Blur', gauss)
cv.imshow('Median Blur', median)

cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ## 8. Bitwise Operations
# **Task:**
# 1. Create a $400 \times 400$ blank image.
# 2. Create a rectangle and a circle on separate blank images.
# 3. Perform Bitwise AND, OR, XOR, and NOT.

# %%
# Write your code here
import cv2 as cv
import numpy as np

# Create a 400x400 blank image
blank = np.zeros((400, 400), dtype='uint8')

# Create rectangle on separate blank image
rectangle = cv.rectangle(blank.copy(),
                         (30, 30),
                         (370, 370),
                         255,
                         -1)

# Create circle on separate blank image
circle = cv.circle(blank.copy(),
                   (200, 200),
                   200,
                   255,
                   -1)

# Bitwise AND
bitwise_and = cv.bitwise_and(rectangle, circle)

# Bitwise OR
bitwise_or = cv.bitwise_or(rectangle, circle)

# Bitwise XOR
bitwise_xor = cv.bitwise_xor(rectangle, circle)

# Bitwise NOT
bitwise_not = cv.bitwise_not(circle)

# Display images
cv.imshow('Rectangle', rectangle)
cv.imshow('Circle', circle)
cv.imshow('AND', bitwise_and)
cv.imshow('OR', bitwise_or)
cv.imshow('XOR', bitwise_xor)
cv.imshow('NOT', bitwise_not)

cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ## 9. Thresholding
# **Task:**
# 1. Load `cats.jpg` and convert to grayscale.
# 2. Apply Simple Thresholding (Binary and Inverse).

# %%
# Write your code here
import cv2 as cv

# Load image
img = cv.imread('opencv_files/cat.jpg')

# Convert to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# Apply Binary Threshold
threshold, thresh = cv.threshold(gray, 150, 255, cv.THRESH_BINARY)

# Apply Inverse Binary Threshold
threshold, thresh_inv = cv.threshold(gray, 150, 255, cv.THRESH_BINARY_INV)

# Display images
cv.imshow('Original Image', img)
cv.imshow('Gray Image', gray)
cv.imshow('Binary Threshold', thresh)
cv.imshow('Inverse Binary Threshold', thresh_inv)

cv.waitKey(0)
cv.destroyAllWindows()
