# %% [markdown]
# # Comprehensive OpenCV Assignment
#
# Follow the instructions in each section and write your code in the provided empty cells using the specified file names.

# %% [markdown]
# ## 1. Reading Images and Videos
# **Task:**
# 1. Read the image `cats.jpg` and display it.
# 2. Read the video `dog.mp4` and display it frame by frame. Ensure the video window closes when the 'd' key is pressed.

# %%
import os

desktop_path = os.path.expanduser("~/Desktop")
print("Your exact Desktop path is:", desktop_path)
print("Files found on your Desktop:", os.listdir(desktop_path))
# Out:
# Your exact Desktop path is: C:\Users\aditi/Desktop
# Files found on your Desktop: ['Activation Eergy_ef0ba27d-e61e-4890-9923-f7b5fa457338 (1).pdf', 'Activation Eergy_ef0ba27d-e61e-4890-9923-f7b5fa457338.pdf', 'Activation Energy of Reaction.docx', 'Activation Energy of Reaction_ADITI.pdf', 'Aditi (Your Chrome) - Chrome.lnk', 'aditi vs code', 'ADITI_250057.zip', 'Arduino IDE.lnk', 'Autodesk Fusion.lnk', 'AUV - Assignment - Extrusion_Aditi.f3d', 'AUV - Assignment - Extrusion_Aditi.step', 'AUV Assignment revolved_Aditi.f3d', 'cat.jpg', 'CHM113M_EndSem_Key_Nov2025_aef1c9b5-5299-4fbf-aa20-82c06049a01a.pdf', 'Cyanotype Blue Printing.docx', 'Cyanotype Blue Printing_aditi.pdf', 'Cyanotype Blue Printing_Aditii.pdf', 'desktop.ini', 'Determination of pI of glycine using pH.docx', 'DIFFERENT SHELLS.docx', 'DIFFERENT SHELLS.pdf', 'docs', 'dog.mp4', 'EDTA Ni titration_aditi.pdf', 'edta.pdf', 'EDTA_aditi.pdf', 'electroverse', 'ENDSEM PREP', 'ESTIMATION OF IODINE IN IODIZED COMMON SALT USING IODOMETRY.docx', 'ESTIMATION OF IODINE IN IODIZED COMMON SALT USING IODOMETRY.pdf', 'ESTIMATION OF IODINE.pdf', 'ESTIMATION OF IODINE_ADITI.pdf', 'fam.jpeg', 'Firefox.exe', 'Google Pixel 3.stp', 'Hackathon_PS_Final.pdf', 'https.docx', 'Iodine in Iodised Salt.pdf', 'Iodine_aditi.pdf', 'Key Quiz 1_276374eb-c5e2-4d34-9f74-956224229261.pdf', 'linear extrusion_aditi', 'mid eval synchro', 'MinGW Installer.lnk', 'modeled racing car.f3d', 'New folder', 'New WinRAR ZIP archive.zip', 'Ni estimation_Aditi.pdf', 'Not a Genius.docx', 'OpenCV_course', 'Opera GX Browser.lnk', 'OverTheWire.docx', 'OverTheWire.pdf', 'park.jpg', 'Password  ZjLjTmM6FvvyRnrb2rfNWOZOT.txt', 'plates', 'plate_ocr.csv', 'Preparation of chm.docx', 'projects', 'QuantVision', 'Quiz - 1_be940dbe-34c2-484e-81b5-621f43605dfb.pdf', 'raw_buffer', 'Revolve_extrusion_aditi', 'signal processing', 'solution_8.pdf.url', 'Thats_a_road', 'Two floored stationary box.f3d', 'Two-Column_Circles_v2.stl', 'Visual Studio Code.lnk', 'WhatsApp Audio 2026-04-16 at 12.12.56 AM.mpeg', 'whatsapp_fixed.mp4', 'y1.jpeg', 'y2.jpeg', 'Y25_Common_Training_Assigments', '~$eparation of chm.docx', '~$erTheWire.docx', '~$FFERENT SHELLS.docx', '~$tivation Energy of Reaction.docx', '~WRL1006.tmp']

# %%
import cv2
import os

desktop = os.path.expanduser("~/Desktop")

img = cv2.imread(os.path.join(desktop, 'cat.jpg'))
cv2.imshow('Cat', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

cap = cv2.VideoCapture(os.path.join(desktop, 'dog.mp4'))
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    cv2.imshow('Dog Video', frame)
    if cv2.waitKey(25) & 0xFF == ord('d'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 2. Drawing and Text
# **Task:**
# 1. Create a blank image of size $500 \times 500$ with 3 color channels.
# 2. Paint a portion of the image red ($[200:300, 300:400]$).
# 3. Draw a green rectangle from $(0,0)$ to the center of the image.
# 4. Draw a red circle at the center with a radius of 40.
# 5. Draw a white line from $(100, 250)$ to $(300, 400)$.

# %%
# Write your code here
import cv2
import numpy as np

img = np.zeros((500, 500, 3), dtype=np.uint8)
img[200:300, 300:400] = [0, 0, 255]
cv2.rectangle(img, (0, 0), (250, 250), (0, 255, 0), 2)
cv2.circle(img, (250, 250), 40, (0, 0, 255), -1)
cv2.line(img, (100, 250), (300, 400), (255, 255, 255), 2)

cv2.imshow('Drawing', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 3. Basic Image Functions
# **Task:**
# 1. Load `park.jpg`.
# 2. Convert it to grayscale.
# 3. Apply Gaussian Blur with a $(7,7)$ kernel.
# 4. Perform Canny Edge detection on the blurred image.

# %%
import cv2
import os

desktop = os.path.expanduser("~/Desktop")

img = cv2.imread(os.path.join(desktop, 'park.jpg'))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (7, 7), 0)
edges = cv2.Canny(blur, 100, 200)

cv2.imshow('Edges', edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 4. Image Transformations
# **Task:**
# 1. Create a function `translate(img, x, y)` to shift an image.
# 2. Create a function `rotate(img, angle, rotPoint=None)` to rotate an image.
# 3. Apply a flip transformation to `park.jpg`.

# %%
# Write your code
import cv2
import numpy as np
import os

desktop = os.path.expanduser("~/Desktop")

def translate(img, x, y):
    transMat = np.float32([[1, 0, x], [0, 1, y]])
    dimensions = (img.shape[1], img.shape[0])
    return cv2.warpAffine(img, transMat, dimensions)

def rotate(img, angle, rotPoint=None):
    (height, width) = img.shape[:2]
    if rotPoint is None:
        rotPoint = (width // 2, height // 2)
    rotMat = cv2.getRotationMatrix2D(rotPoint, angle, 1.0)
    dimensions = (width, height)
    return cv2.warpAffine(img, rotMat, dimensions)

img = cv2.imread(os.path.join(desktop, 'park.jpg'))

translated_img = translate(img, 100, 50)
rotated_img = rotate(img, 45)
flipped_img = cv2.flip(img, 1)

cv2.imshow('Translated', translated_img)
cv2.imshow('Rotated', rotated_img)
cv2.imshow('Flipped', flipped_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 5. Contour Detection
# **Task:**
# 1. Load `cats.jpg`.
# 2. Convert to grayscale and apply Gaussian blur.
# 3. Find the edges using Canny.
# 4. Use `cv.findContours` to find all contours.
# 5. Print the count and draw them on a blank image.

# %%
# Write your code here
import cv2
import numpy as np
import os

desktop = os.path.expanduser("~/Desktop")

img = cv2.imread(os.path.join(desktop, 'cat.jpg'))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (5, 5), 0)
canny = cv2.Canny(blur, 125, 175)

contours, hierarchies = cv2.findContours(canny, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
print(f'{len(contours)} contour(s) found!')

blank = np.zeros(img.shape, dtype=np.uint8)
cv2.drawContours(blank, contours, -1, (0, 255, 0), 1)

cv2.imshow('Contours Drawn', blank)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 141 contour(s) found!

# %% [markdown]
# ## 6. Color Spaces
# **Task:**
# 1. Load `park.jpg`.
# 2. Convert and display in: Gray, HSV,and RGB.

# %%
# Write your code here
import cv2
import os

desktop = os.path.expanduser("~/Desktop")

img = cv2.imread(os.path.join(desktop, 'park.jpg'))

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

cv2.imshow('Gray', gray)
cv2.imshow('HSV', hsv)
cv2.imshow('RGB', rgb)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 7. Smoothing and Blurring
# **Task:**
# 1. Load `cats.jpg`.
# 2. Apply Averaging, Gaussian and Median Blurs

# %%
# Write your code here
import cv2
import os

desktop = os.path.expanduser("~/Desktop")

img = cv2.imread(os.path.join(desktop, 'cat.jpg'))

average = cv2.blur(img, (7, 7))
gaussian = cv2.GaussianBlur(img, (7, 7), 0)
median = cv2.medianBlur(img, 7)

cv2.imshow('Average Blur', average)
cv2.imshow('Gaussian Blur', gaussian)
cv2.imshow('Median Blur', median)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 8. Bitwise Operations
# **Task:**
# 1. Create a $400 \times 400$ blank image.
# 2. Create a rectangle and a circle on separate blank images.
# 3. Perform Bitwise AND, OR, XOR, and NOT.

# %%
# Write your code here
import cv2
import numpy as np

blank1 = np.zeros((400, 400), dtype=np.uint8)
blank2 = np.zeros((400, 400), dtype=np.uint8)

rectangle = cv2.rectangle(blank1.copy(), (30, 30), (370, 370), 255, -1)
circle = cv2.circle(blank2.copy(), (200, 200), 200, 255, -1)

bitwise_and = cv2.bitwise_and(rectangle, circle)
bitwise_or = cv2.bitwise_or(rectangle, circle)
bitwise_xor = cv2.bitwise_xor(rectangle, circle)
bitwise_not = cv2.bitwise_not(rectangle)

cv2.imshow('AND', bitwise_and)
cv2.imshow('OR', bitwise_or)
cv2.imshow('XOR', bitwise_xor)
cv2.imshow('NOT', bitwise_not)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 9. Thresholding
# **Task:**
# 1. Load `cats.jpg` and convert to grayscale.
# 2. Apply Simple Thresholding (Binary and Inverse).

# %%
# Write your code here
import cv2
import os

desktop = os.path.expanduser("~/Desktop")

img = cv2.imread(os.path.join(desktop, 'cat.jpg'))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

threshold, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
threshold_inv, thresh_inv = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)

cv2.imshow('Simple Thresholded', thresh)
cv2.imshow('Simple Thresholded Inverse', thresh_inv)
cv2.waitKey(0)
cv2.destroyAllWindows()
